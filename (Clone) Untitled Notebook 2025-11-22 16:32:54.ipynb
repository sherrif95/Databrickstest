# %%
dbutils.fs.ls("abfss://bronze@becomdataengineer.dfs.core.windows.net/spotify/recently_played/")

# %%
#make first row the header
df = spark.read.csv("abfss://bronze@becomdataengineer.dfs.core.windows.net/spotify/recently_played/", header=True)
display(df)
